# %%
import pandas as pd
from ete3 import NCBITaxa

# %%
# 初始化 NCBITaxa
ncbi = NCBITaxa()

# %%
def get_taxonomy_info(taxid):
    """获取 taxonomy ID 对应的分类信息"""
    try:
        lineage = ncbi.get_lineage(taxid)  # 获取分类层级
        names = ncbi.get_taxid_translator(lineage)  # 获取分类名
        ranks = ncbi.get_rank(lineage)  # 获取分类级别

        # 生成分类信息字典
        rank_dict = {r: names[t] for t, r in ranks.items() if r in ["superkingdom", "phylum", "class", "order", "family", "genus", "species"]}
        
        # 按指定分类级别排列，确保返回 7 个分类
        taxonomy = [rank_dict.get(rank, "") for rank in ["superkingdom", "phylum", "class", "order", "family", "genus", "species"]]
        return taxonomy
    except Exception as e:
        print(f"Error fetching taxonomy for {taxid}: {e}")
        return [""] * 7  # 确保返回 7 个空值

def expand_species_accession(df):
    """拆分 SPECIES_ACCESSION 列，并在原始 df 基础上增加新行"""
    new_rows = []

    for _, row in df.iterrows():
        species_accession = row['SPECIES_ACCESSION']
        if pd.isna(species_accession):  # 处理 NaN
            new_rows.append(row.to_dict())
            continue

        taxids = [x.replace("NCBI:txid", "") for x in str(species_accession).split("{}") if x.startswith("NCBI:txid")]

        for taxid in taxids:
            new_row = row.to_dict()  # 复制原始行数据
            new_row['SPECIES_ACCESSION'] = f"NCBI:txid{taxid}"
            new_rows.append(new_row)

    return pd.DataFrame(new_rows)

def classify_species(df):
    """对扩展后的 df 进行分类"""
    taxonomy_data = []

    for _, row in df.iterrows():
        species_accession = str(row['SPECIES_ACCESSION'])  # 确保是字符串
        
        if pd.isna(row['SPECIES_ACCESSION']) or not species_accession.startswith("NCBI:txid"):
            taxonomy_info = [""] * 7  # 处理 NaN 和异常值
        else:
            taxid = species_accession.replace("NCBI:txid", "")
            taxonomy_info = get_taxonomy_info(int(taxid)) if taxid.isdigit() else [""] * 7

        new_row = row.to_dict()
        new_row.update(dict(zip(["superkingdom", "phylum", "class", "order", "family", "genus", "species"], taxonomy_info)))
        taxonomy_data.append(new_row)

    return pd.DataFrame(taxonomy_data)

# %%
# 读取 CSV
df = pd.read_csv("/Users/ejo/Desktop/chebi_compound.csv", encoding="latin1")
# Out:
# /var/folders/y6/5prks9dj0w11q5d9k3dq9qc40000gn/T/ipykernel_82336/1715102194.py:2: DtypeWarning: Columns (1,5,6,7,19,22,27) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("/Users/ejo/Desktop/chebi_compound.csv", encoding="latin1")

# %%
# 过滤掉 a, b, c 三列同时为空的行
df = df.dropna(subset=['FORMULA', 'MASS', 'MONOISOTOPIC_MASS', 'CHARGE', 'InChI', 'SPECIES', 'SPECIES_ACCESSION'], how='all')

# %%
df
# Out:
#         COMPOUND_ID    FORMULA       MASS  MONOISOTOPIC_MASS  CHARGE  \
# 0       CHEBI:18357   C8H11NO3  169.17780          169.07389     0.0
# 1           CHEBI:3  (C4H6O2)n        NaN                NaN     NaN
# 2       CHEBI:28234   C13H12O2  200.23320          200.08373     0.0
# 3       CHEBI:15399    C10H14O  150.21756          150.10447     0.0
# 4           CHEBI:7     C10H16  136.23404          136.12520     0.0
# ...             ...        ...        ...                ...     ...
# 148478  CHEBI:85274        NaN        NaN                NaN     NaN
# 148479  CHEBI:85331        NaN        NaN                NaN     NaN
# 148480  CHEBI:87032        NaN        NaN                NaN     NaN
# 148481   CHEBI:8735        NaN        NaN                NaN     NaN
# 148482  CHEBI:87442        NaN        NaN                NaN     NaN
#
#                                                     InChI  \
# 0       InChI=1S/C8H11NO3/c9-4-8(12)5-1-2-6(10)7(11)3-...
# 1                                                     NaN
# 2       InChI=1S/C13H12O2/c14-11-6-5-9-7-8-3-1-2-4-10(...
# 3       InChI=1S/C10H14O/c1-7(2)9-5-4-8(3)10(11)6-9/h4...
# 4       InChI=1S/C10H16/c1-7-4-5-8-9(6-7)10(8,2)3/h4,8...
# ...                                                   ...
# 148478                                                NaN
# 148479                                                NaN
# 148480                                                NaN
# 148481                                                NaN
# 148482                                                NaN
#
#                                                 SPECIES  \
# 0                                          Mus musculus
# 1                                          Mus musculus
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 148478                   Streptomyces pristinaespiralis
# 148479                              Pantoea agglomerans
# 148480  Chryseobacterium artocarpi{}Flexibacter elegans
# 148481                                     Mus musculus
# 148482             Synechocystis sp.{}Synechocystis sp.
#
#                      SPECIES_ACCESSION       ID STATUS  ... FOODB.ID  \
# 0                       NCBI:txid10090  18357.0      C  ...      NaN
# 1                       NCBI:txid10090      3.0      E  ...      NaN
# 2                                  NaN  28234.0      C  ...      NaN
# 3                                  NaN  15399.0      C  ...      NaN
# 4                                  NaN      7.0      C  ...      NaN
# ...                                ...      ...    ...  ...      ...
# 148478                  NCBI:txid38300  85274.0      C  ...      NaN
# 148479                    NCBI:txid549  85331.0      C  ...      NaN
# 148480  NCBI:txid1414727{}NCBI:txid997  87032.0      C  ...      NaN
# 148481                  NCBI:txid10090   8735.0      E  ...      NaN
# 148482    NCBI:txid1148{}NCBI:txid1148  87442.0      C  ...      NaN
#
#         METACYC.ID      HMDB.ID    LIPIDMAPS.ID KEGG_DRUG.ID KEGG_GLYCAN.ID  \
# 0              NaN  HMDB0000216             NaN       D00076            NaN
# 1              NaN          NaN             NaN          NaN            NaN
# 2              NaN          NaN             NaN          NaN            NaN
# 3              NaN          NaN             NaN          NaN            NaN
# 4         CPD-8756          NaN  LMPR0102120021          NaN            NaN
# ...            ...          ...             ...          ...            ...
# 148478         NaN          NaN             NaN          NaN            NaN
# 148479         NaN          NaN             NaN          NaN            NaN
# 148480         NaN          NaN             NaN          NaN            NaN
# 148481         NaN          NaN             NaN          NaN            NaN
# 148482         NaN          NaN             NaN          NaN            NaN
#
#           WIKIPEDIA.ID DRUGBANK.ID PUBCHEM.ID  \
# 0       Norepinephrine     DB00368        NaN
# 1                  NaN         NaN        NaN
# 2                  NaN         NaN        NaN
# 3                  NaN         NaN        NaN
# 4                  NaN         NaN        NaN
# ...                ...         ...        ...
# 148478             NaN         NaN        NaN
# 148479             NaN         NaN        NaN
# 148480             NaN         NaN        NaN
# 148481             NaN         NaN        NaN
# 148482             NaN         NaN        NaN
#
#                                                  Synonyms
# 0       Noradrenaline{}L-Noradrenaline{}Norepinephrine...
# 1                            ((R)-3-Hydroxybutanoyl)(n-2)
# 2       (+)-(3S,4R)-cis-3,4-Dihydroxy-3,4-dihydrofluor...
# 3       (+)-(S)-Carvone{}Carvol{}(+)-Carvone{}Carvone{...
# 4       (+)-3-Carene{}(1S,6R)-3,7,7-trimethylbicyclo[4...
# ...                                                   ...
# 148478                      pristinamycine{}pristinamycin
# 148479                                        dapdiamides
# 148480                                                NaN
# 148481                           R{}Methyl group acceptor
# 148482                                                NaN
#
# [148483 rows x 29 columns]

# %%
# 删除 a 列的重复值，仅保留第一次出现的行
df = df.drop_duplicates(subset='COMPOUND_ID', keep='first')

# %%
df
# Out:
#         COMPOUND_ID    FORMULA       MASS  MONOISOTOPIC_MASS  CHARGE  \
# 0       CHEBI:18357   C8H11NO3  169.17780          169.07389     0.0
# 1           CHEBI:3  (C4H6O2)n        NaN                NaN     NaN
# 2       CHEBI:28234   C13H12O2  200.23320          200.08373     0.0
# 3       CHEBI:15399    C10H14O  150.21756          150.10447     0.0
# 4           CHEBI:7     C10H16  136.23404          136.12520     0.0
# ...             ...        ...        ...                ...     ...
# 148478  CHEBI:85274        NaN        NaN                NaN     NaN
# 148479  CHEBI:85331        NaN        NaN                NaN     NaN
# 148480  CHEBI:87032        NaN        NaN                NaN     NaN
# 148481   CHEBI:8735        NaN        NaN                NaN     NaN
# 148482  CHEBI:87442        NaN        NaN                NaN     NaN
#
#                                                     InChI  \
# 0       InChI=1S/C8H11NO3/c9-4-8(12)5-1-2-6(10)7(11)3-...
# 1                                                     NaN
# 2       InChI=1S/C13H12O2/c14-11-6-5-9-7-8-3-1-2-4-10(...
# 3       InChI=1S/C10H14O/c1-7(2)9-5-4-8(3)10(11)6-9/h4...
# 4       InChI=1S/C10H16/c1-7-4-5-8-9(6-7)10(8,2)3/h4,8...
# ...                                                   ...
# 148478                                                NaN
# 148479                                                NaN
# 148480                                                NaN
# 148481                                                NaN
# 148482                                                NaN
#
#                                                 SPECIES  \
# 0                                          Mus musculus
# 1                                          Mus musculus
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 148478                   Streptomyces pristinaespiralis
# 148479                              Pantoea agglomerans
# 148480  Chryseobacterium artocarpi{}Flexibacter elegans
# 148481                                     Mus musculus
# 148482             Synechocystis sp.{}Synechocystis sp.
#
#                      SPECIES_ACCESSION       ID STATUS  ... FOODB.ID  \
# 0                       NCBI:txid10090  18357.0      C  ...      NaN
# 1                       NCBI:txid10090      3.0      E  ...      NaN
# 2                                  NaN  28234.0      C  ...      NaN
# 3                                  NaN  15399.0      C  ...      NaN
# 4                                  NaN      7.0      C  ...      NaN
# ...                                ...      ...    ...  ...      ...
# 148478                  NCBI:txid38300  85274.0      C  ...      NaN
# 148479                    NCBI:txid549  85331.0      C  ...      NaN
# 148480  NCBI:txid1414727{}NCBI:txid997  87032.0      C  ...      NaN
# 148481                  NCBI:txid10090   8735.0      E  ...      NaN
# 148482    NCBI:txid1148{}NCBI:txid1148  87442.0      C  ...      NaN
#
#         METACYC.ID      HMDB.ID    LIPIDMAPS.ID KEGG_DRUG.ID KEGG_GLYCAN.ID  \
# 0              NaN  HMDB0000216             NaN       D00076            NaN
# 1              NaN          NaN             NaN          NaN            NaN
# 2              NaN          NaN             NaN          NaN            NaN
# 3              NaN          NaN             NaN          NaN            NaN
# 4         CPD-8756          NaN  LMPR0102120021          NaN            NaN
# ...            ...          ...             ...          ...            ...
# 148478         NaN          NaN             NaN          NaN            NaN
# 148479         NaN          NaN             NaN          NaN            NaN
# 148480         NaN          NaN             NaN          NaN            NaN
# 148481         NaN          NaN             NaN          NaN            NaN
# 148482         NaN          NaN             NaN          NaN            NaN
#
#           WIKIPEDIA.ID DRUGBANK.ID PUBCHEM.ID  \
# 0       Norepinephrine     DB00368        NaN
# 1                  NaN         NaN        NaN
# 2                  NaN         NaN        NaN
# 3                  NaN         NaN        NaN
# 4                  NaN         NaN        NaN
# ...                ...         ...        ...
# 148478             NaN         NaN        NaN
# 148479             NaN         NaN        NaN
# 148480             NaN         NaN        NaN
# 148481             NaN         NaN        NaN
# 148482             NaN         NaN        NaN
#
#                                                  Synonyms
# 0       Noradrenaline{}L-Noradrenaline{}Norepinephrine...
# 1                            ((R)-3-Hydroxybutanoyl)(n-2)
# 2       (+)-(3S,4R)-cis-3,4-Dihydroxy-3,4-dihydrofluor...
# 3       (+)-(S)-Carvone{}Carvol{}(+)-Carvone{}Carvone{...
# 4       (+)-3-Carene{}(1S,6R)-3,7,7-trimethylbicyclo[4...
# ...                                                   ...
# 148478                      pristinamycine{}pristinamycin
# 148479                                        dapdiamides
# 148480                                                NaN
# 148481                           R{}Methyl group acceptor
# 148482                                                NaN
#
# [148481 rows x 29 columns]

# %%
# **第一步：扩展 `df`，在原始 `df` 上增加行**
df_expanded = expand_species_accession(df)

# %%
def classify_species(df):
    """对扩展后的 df 进行分类"""
    taxonomy_data = []

    for _, row in df.iterrows():
        species_accession = str(row['SPECIES_ACCESSION'])  # 确保是字符串
        
        if pd.isna(row['SPECIES_ACCESSION']) or not species_accession.startswith("NCBI:txid"):
            taxonomy_info = [""] * 7  # 处理 NaN 和异常值
        else:
            taxid = species_accession.replace("NCBI:txid", "")
            taxonomy_info = get_taxonomy_info(int(taxid)) if taxid.isdigit() else [""] * 7

        new_row = row.to_dict()
        new_row.update(dict(zip(["superkingdom", "phylum", "class", "order", "family", "genus", "species"], taxonomy_info)))
        taxonomy_data.append(new_row)

    return pd.DataFrame(taxonomy_data)


df_expanded
# Out:
#         COMPOUND_ID    FORMULA       MASS  MONOISOTOPIC_MASS  CHARGE  \
# 0       CHEBI:18357   C8H11NO3  169.17780          169.07389     0.0
# 1           CHEBI:3  (C4H6O2)n        NaN                NaN     NaN
# 2       CHEBI:28234   C13H12O2  200.23320          200.08373     0.0
# 3       CHEBI:15399    C10H14O  150.21756          150.10447     0.0
# 4           CHEBI:7     C10H16  136.23404          136.12520     0.0
# ...             ...        ...        ...                ...     ...
# 152963  CHEBI:87032        NaN        NaN                NaN     NaN
# 152964  CHEBI:87032        NaN        NaN                NaN     NaN
# 152965   CHEBI:8735        NaN        NaN                NaN     NaN
# 152966  CHEBI:87442        NaN        NaN                NaN     NaN
# 152967  CHEBI:87442        NaN        NaN                NaN     NaN
#
#                                                     InChI  \
# 0       InChI=1S/C8H11NO3/c9-4-8(12)5-1-2-6(10)7(11)3-...
# 1                                                     NaN
# 2       InChI=1S/C13H12O2/c14-11-6-5-9-7-8-3-1-2-4-10(...
# 3       InChI=1S/C10H14O/c1-7(2)9-5-4-8(3)10(11)6-9/h4...
# 4       InChI=1S/C10H16/c1-7-4-5-8-9(6-7)10(8,2)3/h4,8...
# ...                                                   ...
# 152963                                                NaN
# 152964                                                NaN
# 152965                                                NaN
# 152966                                                NaN
# 152967                                                NaN
#
#                                                 SPECIES SPECIES_ACCESSION  \
# 0                                          Mus musculus    NCBI:txid10090
# 1                                          Mus musculus    NCBI:txid10090
# 2                                                   NaN               NaN
# 3                                                   NaN               NaN
# 4                                                   NaN               NaN
# ...                                                 ...               ...
# 152963  Chryseobacterium artocarpi{}Flexibacter elegans  NCBI:txid1414727
# 152964  Chryseobacterium artocarpi{}Flexibacter elegans      NCBI:txid997
# 152965                                     Mus musculus    NCBI:txid10090
# 152966             Synechocystis sp.{}Synechocystis sp.     NCBI:txid1148
# 152967             Synechocystis sp.{}Synechocystis sp.     NCBI:txid1148
#
#              ID STATUS  ... FOODB.ID  METACYC.ID      HMDB.ID    LIPIDMAPS.ID  \
# 0       18357.0      C  ...      NaN         NaN  HMDB0000216             NaN
# 1           3.0      E  ...      NaN         NaN          NaN             NaN
# 2       28234.0      C  ...      NaN         NaN          NaN             NaN
# 3       15399.0      C  ...      NaN         NaN          NaN             NaN
# 4           7.0      C  ...      NaN    CPD-8756          NaN  LMPR0102120021
# ...         ...    ...  ...      ...         ...          ...             ...
# 152963  87032.0      C  ...      NaN         NaN          NaN             NaN
# 152964  87032.0      C  ...      NaN         NaN          NaN             NaN
# 152965   8735.0      E  ...      NaN         NaN          NaN             NaN
# 152966  87442.0      C  ...      NaN         NaN          NaN             NaN
# 152967  87442.0      C  ...      NaN         NaN          NaN             NaN
#
#        KEGG_DRUG.ID KEGG_GLYCAN.ID    WIKIPEDIA.ID DRUGBANK.ID PUBCHEM.ID  \
# 0            D00076            NaN  Norepinephrine     DB00368        NaN
# 1               NaN            NaN             NaN         NaN        NaN
# 2               NaN            NaN             NaN         NaN        NaN
# 3               NaN            NaN             NaN         NaN        NaN
# 4               NaN            NaN             NaN         NaN        NaN
# ...             ...            ...             ...         ...        ...
# 152963          NaN            NaN             NaN         NaN        NaN
# 152964          NaN            NaN             NaN         NaN        NaN
# 152965          NaN            NaN             NaN         NaN        NaN
# 152966          NaN            NaN             NaN         NaN        NaN
# 152967          NaN            NaN             NaN         NaN        NaN
#
#                                                  Synonyms
# 0       Noradrenaline{}L-Noradrenaline{}Norepinephrine...
# 1                            ((R)-3-Hydroxybutanoyl)(n-2)
# 2       (+)-(3S,4R)-cis-3,4-Dihydroxy-3,4-dihydrofluor...
# 3       (+)-(S)-Carvone{}Carvol{}(+)-Carvone{}Carvone{...
# 4       (+)-3-Carene{}(1S,6R)-3,7,7-trimethylbicyclo[4...
# ...                                                   ...
# 152963                                                NaN
# 152964                                                NaN
# 152965                           R{}Methyl group acceptor
# 152966                                                NaN
# 152967                                                NaN
#
# [152968 rows x 29 columns]

# %%
df_classified = classify_species(df_expanded)
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 155871 was translated into 1934393
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /opt/anaconda3/lib/python3.11/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 1000424 was translated into 52477
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /opt/anaconda3/lib/python3.11/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 74465 was translated into 2771340
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /opt/anaconda3/lib/python3.11/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 155873 was translated into 2587399
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /opt/anaconda3/lib/python3.11/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 28575 was translated into 1266744
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /opt/anaconda3/lib/python3.11/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 48122 was translated into 149639
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /opt/anaconda3/lib/python3.11/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 5306 was translated into 2822231
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /opt/anaconda3/lib/python3.11/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 291364 was translated into 2231603
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /opt/anaconda3/lib/python3.11/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 155018 was translated into 2777731
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /opt/anaconda3/lib/python3.11/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 196114 was translated into 2696576
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /opt/anaconda3/lib/python3.11/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 48038 was translated into 2849586
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /opt/anaconda3/lib/python3.11/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 857495 was translated into 509004
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /opt/anaconda3/lib/python3.11/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 204377 was translated into 1352039
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /opt/anaconda3/lib/python3.11/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 484172 was translated into 82017
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /opt/anaconda3/lib/python3.11/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 13007 was translated into 146543
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /opt/anaconda3/lib/python3.11/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 217300 was translated into 693315
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /opt/anaconda3/lib/python3.11/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 157706 was translated into 3151107
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /opt/anaconda3/lib/python3.11/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 544674 was translated into 283120
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /opt/anaconda3/lib/python3.11/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 169768 was translated into 2748384
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /opt/anaconda3/lib/python3.11/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 40433 was translated into 2028083
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /opt/anaconda3/lib/python3.11/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 155247 was translated into 1391944
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /opt/anaconda3/lib/python3.11/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 668470 was translated into 3286444
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /opt/anaconda3/lib/python3.11/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 69406 was translated into 41486
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /opt/anaconda3/lib/python3.11/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 178525 was translated into 2780567
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /opt/anaconda3/lib/python3.11/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 108923 was translated into 2219008
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /opt/anaconda3/lib/python3.11/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 34467 was translated into 2075311
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /opt/anaconda3/lib/python3.11/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 259302 was translated into 206448
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /opt/anaconda3/lib/python3.11/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 132102 was translated into 1659837
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /opt/anaconda3/lib/python3.11/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 5045 was translated into 2046025
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /opt/anaconda3/lib/python3.11/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 65404 was translated into 173545
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /opt/anaconda3/lib/python3.11/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 469282 was translated into 1549217
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /opt/anaconda3/lib/python3.11/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 509205 was translated into 5599
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /opt/anaconda3/lib/python3.11/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 3203 was translated into 463575
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /opt/anaconda3/lib/python3.11/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 993650 was translated into 137887
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /opt/anaconda3/lib/python3.11/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 178516 was translated into 1336945
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /opt/anaconda3/lib/python3.11/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 23810 was translated into 2768810
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /opt/anaconda3/lib/python3.11/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 64635 was translated into 2741558
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /opt/anaconda3/lib/python3.11/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 169181 was translated into 2986133
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /opt/anaconda3/lib/python3.11/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 5532 was translated into 1859699
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /opt/anaconda3/lib/python3.11/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 99905 was translated into 1413812
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /opt/anaconda3/lib/python3.11/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 70342 was translated into 2740835
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /opt/anaconda3/lib/python3.11/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 66889 was translated into 28893
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /opt/anaconda3/lib/python3.11/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 46399 was translated into 228393
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /opt/anaconda3/lib/python3.11/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 13349 was translated into 2813651
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /opt/anaconda3/lib/python3.11/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 41409 was translated into 1405805
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /opt/anaconda3/lib/python3.11/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 87299 was translated into 81056
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /opt/anaconda3/lib/python3.11/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 155874 was translated into 1934356
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /opt/anaconda3/lib/python3.11/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 79816 was translated into 1934379
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /opt/anaconda3/lib/python3.11/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 47794 was translated into 1934371
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /opt/anaconda3/lib/python3.11/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 110149 was translated into 2074842
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /opt/anaconda3/lib/python3.11/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 135650 was translated into 2718965
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /opt/anaconda3/lib/python3.11/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 84593 was translated into 1873
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /opt/anaconda3/lib/python3.11/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 65497 was translated into 2893586
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /opt/anaconda3/lib/python3.11/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 45996 was translated into 264951
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /opt/anaconda3/lib/python3.11/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 531950 was translated into 1437453
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /opt/anaconda3/lib/python3.11/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 140560 was translated into 1736665
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /opt/anaconda3/lib/python3.11/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 134915 was translated into 1898706
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /opt/anaconda3/lib/python3.11/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 333310 was translated into 3621
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /opt/anaconda3/lib/python3.11/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 67334 was translated into 67367
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /opt/anaconda3/lib/python3.11/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 253747 was translated into 126675
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /opt/anaconda3/lib/python3.11/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 183231 was translated into 1663613
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /opt/anaconda3/lib/python3.11/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 186520 was translated into 2906878
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /opt/anaconda3/lib/python3.11/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 172984 was translated into 2025844
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /opt/anaconda3/lib/python3.11/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 159059 was translated into 2901850
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /opt/anaconda3/lib/python3.11/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 1844648 was translated into 2592283
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))

# %%
df_expanded
# Out:
#         COMPOUND_ID    FORMULA       MASS  MONOISOTOPIC_MASS  CHARGE  \
# 0       CHEBI:18357   C8H11NO3  169.17780          169.07389     0.0
# 1           CHEBI:3  (C4H6O2)n        NaN                NaN     NaN
# 2       CHEBI:28234   C13H12O2  200.23320          200.08373     0.0
# 3       CHEBI:15399    C10H14O  150.21756          150.10447     0.0
# 4           CHEBI:7     C10H16  136.23404          136.12520     0.0
# ...             ...        ...        ...                ...     ...
# 152963  CHEBI:87032        NaN        NaN                NaN     NaN
# 152964  CHEBI:87032        NaN        NaN                NaN     NaN
# 152965   CHEBI:8735        NaN        NaN                NaN     NaN
# 152966  CHEBI:87442        NaN        NaN                NaN     NaN
# 152967  CHEBI:87442        NaN        NaN                NaN     NaN
#
#                                                     InChI  \
# 0       InChI=1S/C8H11NO3/c9-4-8(12)5-1-2-6(10)7(11)3-...
# 1                                                     NaN
# 2       InChI=1S/C13H12O2/c14-11-6-5-9-7-8-3-1-2-4-10(...
# 3       InChI=1S/C10H14O/c1-7(2)9-5-4-8(3)10(11)6-9/h4...
# 4       InChI=1S/C10H16/c1-7-4-5-8-9(6-7)10(8,2)3/h4,8...
# ...                                                   ...
# 152963                                                NaN
# 152964                                                NaN
# 152965                                                NaN
# 152966                                                NaN
# 152967                                                NaN
#
#                                                 SPECIES SPECIES_ACCESSION  \
# 0                                          Mus musculus    NCBI:txid10090
# 1                                          Mus musculus    NCBI:txid10090
# 2                                                   NaN               NaN
# 3                                                   NaN               NaN
# 4                                                   NaN               NaN
# ...                                                 ...               ...
# 152963  Chryseobacterium artocarpi{}Flexibacter elegans  NCBI:txid1414727
# 152964  Chryseobacterium artocarpi{}Flexibacter elegans      NCBI:txid997
# 152965                                     Mus musculus    NCBI:txid10090
# 152966             Synechocystis sp.{}Synechocystis sp.     NCBI:txid1148
# 152967             Synechocystis sp.{}Synechocystis sp.     NCBI:txid1148
#
#              ID STATUS  ... FOODB.ID  METACYC.ID      HMDB.ID    LIPIDMAPS.ID  \
# 0       18357.0      C  ...      NaN         NaN  HMDB0000216             NaN
# 1           3.0      E  ...      NaN         NaN          NaN             NaN
# 2       28234.0      C  ...      NaN         NaN          NaN             NaN
# 3       15399.0      C  ...      NaN         NaN          NaN             NaN
# 4           7.0      C  ...      NaN    CPD-8756          NaN  LMPR0102120021
# ...         ...    ...  ...      ...         ...          ...             ...
# 152963  87032.0      C  ...      NaN         NaN          NaN             NaN
# 152964  87032.0      C  ...      NaN         NaN          NaN             NaN
# 152965   8735.0      E  ...      NaN         NaN          NaN             NaN
# 152966  87442.0      C  ...      NaN         NaN          NaN             NaN
# 152967  87442.0      C  ...      NaN         NaN          NaN             NaN
#
#        KEGG_DRUG.ID KEGG_GLYCAN.ID    WIKIPEDIA.ID DRUGBANK.ID PUBCHEM.ID  \
# 0            D00076            NaN  Norepinephrine     DB00368        NaN
# 1               NaN            NaN             NaN         NaN        NaN
# 2               NaN            NaN             NaN         NaN        NaN
# 3               NaN            NaN             NaN         NaN        NaN
# 4               NaN            NaN             NaN         NaN        NaN
# ...             ...            ...             ...         ...        ...
# 152963          NaN            NaN             NaN         NaN        NaN
# 152964          NaN            NaN             NaN         NaN        NaN
# 152965          NaN            NaN             NaN         NaN        NaN
# 152966          NaN            NaN             NaN         NaN        NaN
# 152967          NaN            NaN             NaN         NaN        NaN
#
#                                                  Synonyms
# 0       Noradrenaline{}L-Noradrenaline{}Norepinephrine...
# 1                            ((R)-3-Hydroxybutanoyl)(n-2)
# 2       (+)-(3S,4R)-cis-3,4-Dihydroxy-3,4-dihydrofluor...
# 3       (+)-(S)-Carvone{}Carvol{}(+)-Carvone{}Carvone{...
# 4       (+)-3-Carene{}(1S,6R)-3,7,7-trimethylbicyclo[4...
# ...                                                   ...
# 152963                                                NaN
# 152964                                                NaN
# 152965                           R{}Methyl group acceptor
# 152966                                                NaN
# 152967                                                NaN
#
# [152968 rows x 29 columns]

# %%
output_file = "/Users/ejo/Desktop/chebi_origin.csv"

# %%
# **保存为 CSV**
df_expanded.to_csv(output_file, index=False, encoding="utf-8")

# %%
df_classified.to_csv(output_file, index=False, encoding="utf-8")
